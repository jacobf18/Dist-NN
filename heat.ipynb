# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/Hyperlocal_Temperature_Monitoring.csv', parse_dates=['Day'])

# %%
data
# Out:
#         Sensor.ID    AirTemp        Day  Hour   Latitude  Longitude  Year  \
# 0        Bk-BR_01  71.189000 2018-06-15     1  40.666205  -73.91691  2018
# 1        Bk-BR_01  70.243333 2018-06-15     2  40.666205  -73.91691  2018
# 2        Bk-BR_01  69.392667 2018-06-15     3  40.666205  -73.91691  2018
# 3        Bk-BR_01  68.263167 2018-06-15     4  40.666205  -73.91691  2018
# 4        Bk-BR_01  67.114000 2018-06-15     5  40.666205  -73.91691  2018
# ...           ...        ...        ...   ...        ...        ...   ...
# 2097145   Q-CH_26  78.346667 2019-09-07    15  40.699578  -73.73876  2019
# 2097146   Q-CH_26  79.517167 2019-09-07    16  40.699578  -73.73876  2019
# 2097147   Q-CH_26  77.203667 2019-09-07    17  40.699578  -73.73876  2019
# 2097148   Q-CH_26  75.696000 2019-09-07    18  40.699578  -73.73876  2019
# 2097149   Q-CH_26  72.359000 2019-09-07    19  40.699578  -73.73876  2019
#
#         Install.Type   Borough ntacode
# 0        Street Tree  Brooklyn    BK81
# ...

# %%
data['Sensor.ID'].unique().shape
# Out:
# (423,)

# %%
data.Latitude.unique().shape
# Out:
# (434,)

# %%
data_day1 = data[data.Day == '2018-06-15']

# %%
data_day1
# Out:
#         Sensor.ID    AirTemp        Day  Hour   Latitude  Longitude  Year  \
# 0        Bk-BR_01  71.189000 2018-06-15     1  40.666205 -73.916910  2018
# 1        Bk-BR_01  70.243333 2018-06-15     2  40.666205 -73.916910  2018
# 2        Bk-BR_01  69.392667 2018-06-15     3  40.666205 -73.916910  2018
# 3        Bk-BR_01  68.263167 2018-06-15     4  40.666205 -73.916910  2018
# 4        Bk-BR_01  67.114000 2018-06-15     5  40.666205 -73.916910  2018
# ...           ...        ...        ...   ...        ...        ...   ...
# 1046558   Q-JC_04  82.541333 2018-06-15    19  40.699953 -73.777503  2018
# 1046559   Q-JC_04  75.849167 2018-06-15    20  40.699953 -73.777503  2018
# 1046560   Q-JC_04  73.041000 2018-06-15    21  40.699953 -73.777503  2018
# 1046561   Q-JC_04  70.215000 2018-06-15    22  40.699953 -73.777503  2018
# 1046562   Q-JC_04  68.477333 2018-06-15    23  40.699953 -73.777503  2018
#
#         Install.Type   Borough ntacode
# 0        Street Tree  Brooklyn    BK81
# ...
